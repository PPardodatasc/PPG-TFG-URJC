# %% [markdown]
# # 2019 Dataset - EDA

# %% [markdown]
# - **df_500k**: 500.000 primeras muestras del conjunto de datos original.
#
# - **df_500k_mod**: dataset original modificado con nuevas variables y procesamiento.
#
# - **df_500k_model**: dataset con features seleccionadas para la posterior imputación de datos y entrenamiento de los modelos

# %%
import pandas as pd
import os

data_folder = os.path.join("../..", "data")
csv_name = "On-street_Car_Parking_Sensor_Data_-_2019.csv"
csv_path = os.path.join(data_folder, csv_name)

df_500k = pd.read_csv(csv_path, nrows=500000, low_memory=False) # low_memory=False to avoid dtype inference issues with mixed types
df_500k.info()
display(df_500k.head())
df_500k.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DeviceId          500000 non-null  int64
#  1   ArrivalTime       500000 non-null  str
#  2   DepartureTime     500000 non-null  str
#  3   DurationMinutes   500000 non-null  str
#  4   StreetMarker      500000 non-null  str
#  5   SignPlateID       328141 non-null  float64
#  6   Sign              328141 non-null  str
#  7   AreaName          500000 non-null  str
#  8   StreetId          500000 non-null  int64
#  9   StreetName        500000 non-null  str
#  10  BetweenStreet1ID  500000 non-null  int64
#  11  BetweenStreet1    500000 non-null  str
#  12  BetweenStreet2ID  500000 non-null  int64
#  13  BetweenStreet2    500000 non-null  str
#  14  SideOfStreet      500000 non-null  int64
#  15  SideOfStreetCode  500000 non-null  str
#  16  SideName          500000 non-null  str
#  17  BayId             500000 non-null  int64
#  18  InViolation       500000 non-null  bool
#  19  VehiclePresent    500000 non-null  bool
# dtypes: bool(2), float64(1), int64(6), str(11)
# memory usage: 129.3 MB
#    DeviceId             ArrivalTime           DepartureTime DurationMinutes  \
# 0     23915  11/03/2019 03:00:56 AM  11/03/2019 03:07:26 AM               7
# 1     23914  04/16/2019 02:14:47 PM  04/16/2019 02:15:23 PM               1
# 2     23913  09/29/2019 01:08:22 AM  09/29/2019 01:31:41 AM              23
# 3     23915  06/05/2019 06:59:17 PM  06/05/2019 06:59:24 PM               0
# 4     23915  04/01/2019 07:03:41 AM  04/01/2019 07:14:12 AM              11
#
#   StreetMarker  SignPlateID                        Sign     AreaName  \
# 0        2374N          NaN                         NaN      Windsor
# 1        1896N        287.0     1P MTR M-SAT 7:30-18:30  Twin Towers
# 2        1581S          NaN                         NaN        Banks
# 3        2374N        508.0  2P MTR M-SAT 18.30 - 20.30      Windsor
# 4        2374N          NaN                         NaN      Windsor
#
#    StreetId       StreetName  BetweenStreet1ID     BetweenStreet1  \
# 0       123    BOURKE STREET              1221     RUSSELL STREET
# 1       528   COLLINS STREET               647  EXHIBITION STREET
# 2       670  FLINDERS STREET              1171       QUEEN STREET
# 3       123    BOURKE STREET              1221     RUSSELL STREET
# 4       123    BOURKE STREET              1221     RUSSELL STREET
#
#    BetweenStreet2ID     BetweenStreet2  SideOfStreet SideOfStreetCode  \
# 0               647  EXHIBITION STREET             3                N
# 1              1288      SPRING STREET             3                N
# 2               627   ELIZABETH STREET             4                S
# 3               647  EXHIBITION STREET             3                N
# 4               647  EXHIBITION STREET             3                N
#
#   SideName  BayId  InViolation  VehiclePresent
# 0    North   1753        False           False
# 1    North   1532        False           False
# 2    South   1399        False           False
# 3    North   1753        False           False
# 4    North   1753        False            True
#              DeviceId             ArrivalTime           DepartureTime  \
# count   500000.000000                  500000                  500000
# unique            NaN                  445527                  446116
# top               NaN  05/03/2019 12:00:00 AM  05/03/2019 12:00:00 AM
# freq              NaN                      67                      83
# mean     23960.151398                     NaN                     NaN
# std         67.882774                     NaN                     NaN
# min      23913.000000                     NaN                     NaN
# 25%      23931.000000                     NaN                     NaN
# 50%      23970.000000                     NaN                     NaN
# 75%      23983.000000                     NaN                     NaN
# max      28287.000000                     NaN                     NaN
#
#        DurationMinutes StreetMarker    SignPlateID                     Sign  \
# count           500000       500000  328141.000000                   328141
# unique             871          307            NaN                      115
# top                  1          53W            NaN  LZ 15M M-SUN 7:30-19:30
# freq             64400        35007            NaN                    35417
# mean               NaN          NaN     264.700958                      NaN
# std                NaN          NaN     217.613039                      NaN
# min                NaN          NaN       2.000000                      NaN
# 25%                NaN          NaN     111.000000                      NaN
# 50%                NaN          NaN     205.000000                      NaN
# 75%                NaN          NaN     508.000000                      NaN
# max                NaN          NaN     740.000000                      NaN
#
#                AreaName       StreetId       StreetName  BetweenStreet1ID  \
# count            500000  500000.000000           500000     500000.000000
# unique               36            NaN               64               NaN
# top     Princes Theatre            NaN  LONSDALE STREET               NaN
# freq              72942            NaN            66026               NaN
# mean                NaN     869.611016              NaN       1033.815606
# std                 NaN     374.161998              NaN        313.950150
# min                 NaN       5.000000              NaN          5.000000
# 25%                 NaN     617.000000              NaN        839.000000
# 50%                 NaN     894.000000              NaN       1171.000000
# 75%                 NaN    1288.000000              NaN       1285.000000
# max                 NaN    1428.000000              NaN       1455.000000
#
#        BetweenStreet1  BetweenStreet2ID  BetweenStreet2   SideOfStreet  \
# count          500000     500000.000000          500000  500000.000000
# unique             64               NaN              65            NaN
# top       KING STREET               NaN  WILLIAM STREET            NaN
# freq            62658               NaN           65266            NaN
# mean              NaN        842.122280             NaN       3.050092
# std               NaN        480.408987             NaN       1.389843
# min               NaN         79.000000             NaN       1.000000
# 25%               NaN        528.000000             NaN       2.000000
# 50%               NaN        894.000000             NaN       3.000000
# 75%               NaN       1299.000000             NaN       4.000000
# max               NaN       1457.000000             NaN       5.000000
#
#        SideOfStreetCode SideName          BayId InViolation VehiclePresent
# count            500000   500000  500000.000000      500000         500000
# unique                5        5            NaN           2              2
# top                   S    South            NaN       False           True
# freq             113512   113512            NaN      481769         266795
# mean                NaN      NaN    2838.099810         NaN            NaN
# std                 NaN      NaN    1850.571659         NaN            NaN
# min                 NaN      NaN     568.000000         NaN            NaN
# 25%                 NaN      NaN    1338.000000         NaN            NaN
# 50%                 NaN      NaN    2374.000000         NaN            NaN
# 75%                 NaN      NaN    4126.000000         NaN            NaN
# max                 NaN      NaN    8790.000000         NaN            NaN

# %% [markdown]
# ### Missing values

# %%
# Check for missing values
missing_values = df_500k.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# DeviceId                 0
# ArrivalTime              0
# DepartureTime            0
# DurationMinutes          0
# StreetMarker             0
# SignPlateID         171859
# Sign                171859
# AreaName                 0
# StreetId                 0
# StreetName               0
# BetweenStreet1ID         0
# BetweenStreet1           0
# BetweenStreet2ID         0
# BetweenStreet2           0
# SideOfStreet             0
# SideOfStreetCode         0
# SideName                 0
# BayId                    0
# InViolation              0
# VehiclePresent           0
# dtype: int64

# %% [markdown]
# ### Unique values

# %%
# See unique values
unique_values = df_500k.nunique()
print("\nUnique values in each column:")
print(unique_values)
# Out:
# Unique values in each column:
# DeviceId               307
# ArrivalTime         445527
# DepartureTime       446116
# DurationMinutes        871
# StreetMarker           307
# SignPlateID            116
# Sign                   115
# AreaName                36
# StreetId                64
# StreetName              64
# BetweenStreet1ID        64
# BetweenStreet1          64
# BetweenStreet2ID        65
# BetweenStreet2          65
# SideOfStreet             5
# SideOfStreetCode         5
# SideName                 5
# BayId                  307
# InViolation              2
# VehiclePresent           2
# dtype: int64

# %% [markdown]
# ### Conversión de DurationMinutes: str --> float

# %%
# Make a copy of original df to save modifications
df_500k_mod = df_500k.copy()

# Inspect values in DurationMinutes column, as they are str type and they should probably be int or float
duration_numeric = pd.to_numeric(df_500k_mod['DurationMinutes'], errors='coerce')
problematic = df_500k_mod[duration_numeric.isna()]['DurationMinutes'].unique()

print(f"Valores no numéricos únicos: {len(problematic)}")
print(f"Detalle de los primeros 10 valores no numéricos:")
for i, val in enumerate(problematic[:10]):
    print(f"  {i+1}. Valor: '{val}'")
# Values contain commas, as European style for decimals

valid = df_500k_mod[~duration_numeric.isna()]['DurationMinutes'].unique()
print(f"\nValores válidos numéricos únicos: {len(valid)}")
print(f"Detalle de los primeros 5 valores numéricos:")
for i, val in enumerate(valid[:5]):
    numeric_val = pd.to_numeric(val)
    print(f"  {i+1}. Valor: '{val}'")

# Replace commas with dots and convert to float
df_500k_mod['DurationMinutes'] = df_500k_mod['DurationMinutes'].str.replace(',', '.').astype(float)
print("\nEstadísticas después de la conversión:")
print(f"Total de filas: {len(df_500k_mod)}")
print(f"Valores válidos: {df_500k_mod['DurationMinutes'].notna().sum()}, tipo: {df_500k_mod['DurationMinutes'].dtype}")
print(f"Valores inválidos (NaN): {df_500k_mod['DurationMinutes'].isna().sum()}")
# Out:
# Valores no numéricos únicos: 43
# Detalle de los primeros 10 valores no numéricos:
#   1. Valor: '1,440'
#   2. Valor: '1,111'
#   3. Valor: '1,334'
#   4. Valor: '1,314'
#   5. Valor: '1,166'
#   6. Valor: '1,094'
#   7. Valor: '1,139'
#   8. Valor: '1,303'
#   9. Valor: '1,275'
#   10. Valor: '1,045'
#
# Valores válidos numéricos únicos: 828
# Detalle de los primeros 5 valores numéricos:
#   1. Valor: '7'
#   2. Valor: '1'
#   3. Valor: '23'
#   4. Valor: '0'
#   5. Valor: '11'
#
# Estadísticas después de la conversión:
# Total de filas: 500000
# Valores válidos: 500000, tipo: float64
# Valores inválidos (NaN): 0

# %% [markdown]
# ### Conversión de variables temporales: str --> dateTime

# %%
# Convert time variables to dateTime format
df_500k_mod['ArrivalTime'] = pd.to_datetime(df_500k_mod['ArrivalTime'])
df_500k_mod['DepartureTime'] = pd.to_datetime(df_500k_mod['DepartureTime'])
print(df_500k_mod[['ArrivalTime', 'DepartureTime']].info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ArrivalTime    500000 non-null  datetime64[us]
#  1   DepartureTime  500000 non-null  datetime64[us]
# dtypes: datetime64[us](2)
# memory usage: 7.6 MB
# None

# %% [markdown]
# ### Estadísticas tras la modificación de variables del dataset

# %%
df_500k_mod.describe(include='all')
# Out:
#              DeviceId                 ArrivalTime               DepartureTime  \
# count   500000.000000                      500000                      500000
# unique            NaN                         NaN                         NaN
# top               NaN                         NaN                         NaN
# freq              NaN                         NaN                         NaN
# mean     23960.151398  2019-07-07 22:14:17.078831  2019-07-07 23:05:10.439355
# min      23913.000000         2019-01-01 00:00:00         2019-01-01 00:04:37
# 25%      23931.000000  2019-04-15 08:23:08.250000  2019-04-15 08:44:08.250000
# 50%      23970.000000  2019-07-10 11:39:20.500000  2019-07-10 12:13:46.500000
# 75%      23983.000000  2019-10-02 20:20:42.250000  2019-10-02 20:52:55.750000
# max      28287.000000         2019-12-31 23:53:12         2019-12-31 23:58:14
# std         67.882774                         NaN                         NaN
#
#         DurationMinutes StreetMarker    SignPlateID                     Sign  \
# count     500000.000000       500000  328141.000000                   328141
# unique              NaN          307            NaN                      115
# top                 NaN          53W            NaN  LZ 15M M-SUN 7:30-19:30
# freq                NaN        35007            NaN                    35417
# mean          50.550586          NaN     264.700958                      NaN
# min            0.000000          NaN       2.000000                      NaN
# 25%            2.000000          NaN     111.000000                      NaN
# 50%           10.000000          NaN     205.000000                      NaN
# 75%           48.000000          NaN     508.000000                      NaN
# max          981.000000          NaN     740.000000                      NaN
# std           99.345009          NaN     217.613039                      NaN
#
#                AreaName       StreetId       StreetName  BetweenStreet1ID  \
# count            500000  500000.000000           500000     500000.000000
# unique               36            NaN               64               NaN
# top     Princes Theatre            NaN  LONSDALE STREET               NaN
# freq              72942            NaN            66026               NaN
# mean                NaN     869.611016              NaN       1033.815606
# min                 NaN       5.000000              NaN          5.000000
# 25%                 NaN     617.000000              NaN        839.000000
# 50%                 NaN     894.000000              NaN       1171.000000
# 75%                 NaN    1288.000000              NaN       1285.000000
# max                 NaN    1428.000000              NaN       1455.000000
# std                 NaN     374.161998              NaN        313.950150
#
#        BetweenStreet1  BetweenStreet2ID  BetweenStreet2   SideOfStreet  \
# count          500000     500000.000000          500000  500000.000000
# unique             64               NaN              65            NaN
# top       KING STREET               NaN  WILLIAM STREET            NaN
# freq            62658               NaN           65266            NaN
# mean              NaN        842.122280             NaN       3.050092
# min               NaN         79.000000             NaN       1.000000
# 25%               NaN        528.000000             NaN       2.000000
# 50%               NaN        894.000000             NaN       3.000000
# 75%               NaN       1299.000000             NaN       4.000000
# max               NaN       1457.000000             NaN       5.000000
# std               NaN        480.408987             NaN       1.389843
#
#        SideOfStreetCode SideName          BayId InViolation VehiclePresent
# count            500000   500000  500000.000000      500000         500000
# unique                5        5            NaN           2              2
# top                   S    South            NaN       False           True
# freq             113512   113512            NaN      481769         266795
# mean                NaN      NaN    2838.099810         NaN            NaN
# min                 NaN      NaN     568.000000         NaN            NaN
# 25%                 NaN      NaN    1338.000000         NaN            NaN
# 50%                 NaN      NaN    2374.000000         NaN            NaN
# 75%                 NaN      NaN    4126.000000         NaN            NaN
# max                 NaN      NaN    8790.000000         NaN            NaN
# std                 NaN      NaN    1850.571659         NaN            NaN

# %% [markdown]
# ### Inspeccionar matches entre variables

# %%
# Identify matches between SideOfStreet and SideOfStreetCode
matches=[]
for fila in df_500k.itertuples():
    SideOfStreet = fila.SideOfStreet
    SideOfStreetCode = fila.SideOfStreetCode
    if not any(m[0] == SideOfStreet for m in matches):
        matches.append((SideOfStreet, SideOfStreetCode))
        print(f"New match found: SideOfStreet {SideOfStreet} matches SideOfStreetCode {SideOfStreetCode}")
    else:
        if (SideOfStreet, SideOfStreetCode) not in matches:
            print(f"Mismatch found: SideOfStreet {SideOfStreet} does not match SideOfStreetCode {SideOfStreetCode}")

unique_side_of_streets = df_500k['SideOfStreet'].unique()
unique_side_of_street_codes = df_500k['SideOfStreetCode'].unique()
print(f"Unique SideOfStreets: {len(unique_side_of_streets)}")
print(f"Unique SideOfStreetCodes: {len(unique_side_of_street_codes)}")
# Out:
# New match found: SideOfStreet 3 matches SideOfStreetCode N
# New match found: SideOfStreet 4 matches SideOfStreetCode S
# New match found: SideOfStreet 5 matches SideOfStreetCode W
# New match found: SideOfStreet 1 matches SideOfStreetCode C
# New match found: SideOfStreet 2 matches SideOfStreetCode E
# Unique SideOfStreets: 5
# Unique SideOfStreetCodes: 5

# %%
# Identify matches between DeviceId and StreetMarker 
matches=[]
for fila in df_500k.itertuples():
    device_id = fila.DeviceId
    street_marker = fila.StreetMarker
    if not any(m[0] == device_id for m in matches):
        matches.append((device_id, street_marker))
        print(f"New match found: DeviceId {device_id} matches StreetMarker {street_marker}")
    else:
        if (device_id, street_marker) not in matches:
            print(f"Mismatch found: DeviceId {device_id} does not match StreetMarker {street_marker}")

unique_device_ids = df_500k['DeviceId'].unique()
unique_street_markers = df_500k['StreetMarker'].unique()
print(f"Unique DeviceIds: {len(unique_device_ids)}")
print(f"Unique StreetMarkers: {len(unique_street_markers)}")
# Out:
# New match found: DeviceId 23915 matches StreetMarker 2374N
# New match found: DeviceId 23914 matches StreetMarker 1896N
# New match found: DeviceId 23913 matches StreetMarker 1581S
# New match found: DeviceId 23916 matches StreetMarker 2334N
# New match found: DeviceId 27446 matches StreetMarker 6571S
# New match found: DeviceId 27164 matches StreetMarker 1291W
# New match found: DeviceId 25982 matches StreetMarker C726
# New match found: DeviceId 25433 matches StreetMarker 15092E
# New match found: DeviceId 27596 matches StreetMarker 767Wa
# New match found: DeviceId 26585 matches StreetMarker 12811S
# New match found: DeviceId 26445 matches StreetMarker 13345W
# New match found: DeviceId 26632 matches StreetMarker 4466E
# New match found: DeviceId 25520 matches StreetMarker 15182N
# New match found: DeviceId 25724 matches StreetMarker 3958N
# New match found: DeviceId 26754 matches StreetMarker 3668N
# New match found: DeviceId 23944 matches StreetMarker 3166N
# New match found: DeviceId 23941 matches StreetMarker 1355W
# New match found: DeviceId 23945 matches StreetMarker 3413S
# New match found: DeviceId 23940 matches StreetMarker 1405W
# New match found: DeviceId 23939 matches StreetMarker 5534E
# New match found: DeviceId 23918 matches StreetMarker 3498N
# New match found: DeviceId 23920 matches StreetMarker 3944N
# New match found: DeviceId 23917 matches StreetMarker C2918
# New match found: DeviceId 23919 matches StreetMarker 3496N
# New match found: DeviceId 28287 matches StreetMarker 8331W
# New match found: DeviceId 25707 matches StreetMarker 14072E
# New match found: DeviceId 27592 matches StreetMarker 6660N
# New match found: DeviceId 27120 matches StreetMarker 6035S
# New match found: DeviceId 25746 matches StreetMarker 7063S
# New match found: DeviceId 24602 matches StreetMarker 5331W
# New match found: DeviceId 25600 matches StreetMarker 15249S
# New match found: DeviceId 26228 matches StreetMarker 3012N
# New match found: DeviceId 26344 matches StreetMarker C7220
# New match found: DeviceId 27071 matches StreetMarker 12303S
# New match found: DeviceId 26086 matches StreetMarker 10174E
# New match found: DeviceId 25060 matches StreetMarker 3339S
# New match found: DeviceId 26471 matches StreetMarker 3957S
# New match found: DeviceId 26281 matches StreetMarker C5860
# New match found: DeviceId 27498 matches StreetMarker 3266N
# New match found: DeviceId 27531 matches StreetMarker 10051S
# New match found: DeviceId 27241 matches StreetMarker 1708N
# New match found: DeviceId 26470 matches StreetMarker 3955S
# New match found: DeviceId 27271 matches StreetMarker 13673W
# New match found: DeviceId 28174 matches StreetMarker 12104E
# New match found: DeviceId 27294 matches StreetMarker 910E
# New match found: DeviceId 24533 matches StreetMarker 1579S
# New match found: DeviceId 27595 matches StreetMarker 769W
# New match found: DeviceId 26945 matches StreetMarker 10176E
# New match found: DeviceId 26259 matches StreetMarker C6642
# New match found: DeviceId 25069 matches StreetMarker 427W
# New match found: DeviceId 26869 matches StreetMarker 2327S
# New match found: DeviceId 25771 matches StreetMarker 558E
# New match found: DeviceId 26388 matches StreetMarker 1404E
# New match found: DeviceId 23928 matches StreetMarker 10182E
# New match found: DeviceId 23921 matches StreetMarker 7064N
# New match found: DeviceId 23927 matches StreetMarker 5818E
# New match found: DeviceId 23922 matches StreetMarker C7194
# New match found: DeviceId 23925 matches StreetMarker 5832E
# New match found: DeviceId 23924 matches StreetMarker C7236
# New match found: DeviceId 23923 matches StreetMarker C7166
# New match found: DeviceId 26574 matches StreetMarker 1549W
# New match found: DeviceId 26462 matches StreetMarker 2219S
# New match found: DeviceId 27505 matches StreetMarker 1722N
# New match found: DeviceId 27644 matches StreetMarker 1862N
# New match found: DeviceId 26562 matches StreetMarker 1439W
# New match found: DeviceId 27399 matches StreetMarker 3411S
# New match found: DeviceId 26012 matches StreetMarker 1337W
# New match found: DeviceId 26472 matches StreetMarker 3388N
# New match found: DeviceId 27245 matches StreetMarker 2000N
# New match found: DeviceId 26121 matches StreetMarker 283W
# New match found: DeviceId 25937 matches StreetMarker 1458E
# New match found: DeviceId 26814 matches StreetMarker C312
# New match found: DeviceId 27243 matches StreetMarker 13041S
# New match found: DeviceId 26375 matches StreetMarker 4907W
# New match found: DeviceId 26548 matches StreetMarker 5324E
# New match found: DeviceId 26669 matches StreetMarker 2855S
# New match found: DeviceId 26852 matches StreetMarker 1481W
# New match found: DeviceId 26385 matches StreetMarker 1435W
# New match found: DeviceId 25988 matches StreetMarker C504
# New match found: DeviceId 27173 matches StreetMarker 13228N
# New match found: DeviceId 26908 matches StreetMarker 3836N
# New match found: DeviceId 26169 matches StreetMarker 18E
# New match found: DeviceId 26376 matches StreetMarker 4841W
# New match found: DeviceId 24702 matches StreetMarker 13446E
# New match found: DeviceId 26710 matches StreetMarker 13342E
# New match found: DeviceId 26547 matches StreetMarker 5318E
# New match found: DeviceId 26189 matches StreetMarker 2002N
# New match found: DeviceId 26403 matches StreetMarker 2702N
# New match found: DeviceId 28208 matches StreetMarker C7708
# New match found: DeviceId 26727 matches StreetMarker C5874
# New match found: DeviceId 26707 matches StreetMarker 10200E
# New match found: DeviceId 26381 matches StreetMarker 1301W
# New match found: DeviceId 23935 matches StreetMarker 12506N
# New match found: DeviceId 23938 matches StreetMarker C3084
# New match found: DeviceId 23931 matches StreetMarker 7724N
# New match found: DeviceId 23933 matches StreetMarker C9190
# New match found: DeviceId 23932 matches StreetMarker 5284E
# New match found: DeviceId 23937 matches StreetMarker 138E
# New match found: DeviceId 23934 matches StreetMarker 12418N
# New match found: DeviceId 23930 matches StreetMarker 6243W
# New match found: DeviceId 23936 matches StreetMarker 8661W
# New match found: DeviceId 25121 matches StreetMarker C5854
# New match found: DeviceId 26509 matches StreetMarker 429W
# New match found: DeviceId 26913 matches StreetMarker 6661S
# New match found: DeviceId 26734 matches StreetMarker 12079W
# New match found: DeviceId 27004 matches StreetMarker 3456NA
# New match found: DeviceId 25242 matches StreetMarker 15502N
# New match found: DeviceId 26291 matches StreetMarker 10153W
# New match found: DeviceId 26496 matches StreetMarker 2137S
# New match found: DeviceId 26332 matches StreetMarker 13001S
# New match found: DeviceId 23929 matches StreetMarker 7720N
# New match found: DeviceId 25011 matches StreetMarker 10170E
# New match found: DeviceId 27658 matches StreetMarker 20192N
# New match found: DeviceId 26398 matches StreetMarker 3099S
# New match found: DeviceId 26244 matches StreetMarker 3964N
# New match found: DeviceId 26634 matches StreetMarker 4461W
# New match found: DeviceId 26878 matches StreetMarker 2400N
# New match found: DeviceId 26860 matches StreetMarker 1777S
# New match found: DeviceId 26699 matches StreetMarker 12219S
# New match found: DeviceId 26888 matches StreetMarker 3194N
# New match found: DeviceId 28069 matches StreetMarker 12315S
# New match found: DeviceId 26990 matches StreetMarker 13434E
# New match found: DeviceId 27096 matches StreetMarker 3197S
# New match found: DeviceId 27466 matches StreetMarker C6706
# New match found: DeviceId 25111 matches StreetMarker 7554N
# New match found: DeviceId 26404 matches StreetMarker C3164
# New match found: DeviceId 26758 matches StreetMarker 392E
# New match found: DeviceId 28078 matches StreetMarker 3008N
# New match found: DeviceId 27074 matches StreetMarker 12286N
# New match found: DeviceId 26873 matches StreetMarker C13524
# New match found: DeviceId 24597 matches StreetMarker 6676N
# New match found: DeviceId 26235 matches StreetMarker 3414N
# New match found: DeviceId 26975 matches StreetMarker 14050E
# New match found: DeviceId 28110 matches StreetMarker 11925W
# New match found: DeviceId 26980 matches StreetMarker 11870E
# New match found: DeviceId 25043 matches StreetMarker 1899S
# New match found: DeviceId 27066 matches StreetMarker 12408N
# New match found: DeviceId 27402 matches StreetMarker 3417S
# New match found: DeviceId 25764 matches StreetMarker C208
# New match found: DeviceId 26233 matches StreetMarker 3568N
# New match found: DeviceId 26423 matches StreetMarker 10199W
# New match found: DeviceId 26918 matches StreetMarker C7028
# New match found: DeviceId 25268 matches StreetMarker 15546N
# New match found: DeviceId 26188 matches StreetMarker 1732N
# New match found: DeviceId 26583 matches StreetMarker 7060N
# New match found: DeviceId 27344 matches StreetMarker 12019W
# New match found: DeviceId 25194 matches StreetMarker C2944
# New match found: DeviceId 26877 matches StreetMarker 2441S
# New match found: DeviceId 27225 matches StreetMarker 3697S
# New match found: DeviceId 23967 matches StreetMarker 13085S
# New match found: DeviceId 23970 matches StreetMarker 53W
# New match found: DeviceId 23966 matches StreetMarker C9198
# New match found: DeviceId 26816 matches StreetMarker 627W
# New match found: DeviceId 26742 matches StreetMarker 12067W
# New match found: DeviceId 26359 matches StreetMarker C1109
# New match found: DeviceId 25975 matches StreetMarker 330Eb
# New match found: DeviceId 27191 matches StreetMarker 11720E
# New match found: DeviceId 26876 matches StreetMarker 2443S
# New match found: DeviceId 26568 matches StreetMarker 1478E
# New match found: DeviceId 26536 matches StreetMarker 1188E
# New match found: DeviceId 26392 matches StreetMarker 1787S
# New match found: DeviceId 26750 matches StreetMarker 3660N
# New match found: DeviceId 25970 matches StreetMarker 13432E
# New match found: DeviceId 27457 matches StreetMarker 1335W
# New match found: DeviceId 25949 matches StreetMarker 7090N
# New match found: DeviceId 24580 matches StreetMarker 3834N
# New match found: DeviceId 26107 matches StreetMarker 13305W
# New match found: DeviceId 26382 matches StreetMarker 1489W
# New match found: DeviceId 25253 matches StreetMarker 15516N
# New match found: DeviceId 27870 matches StreetMarker 20485W
# New match found: DeviceId 27048 matches StreetMarker 1444E
# New match found: DeviceId 25934 matches StreetMarker 1398E
# New match found: DeviceId 23971 matches StreetMarker 102E
# New match found: DeviceId 23974 matches StreetMarker 3873S
# New match found: DeviceId 23972 matches StreetMarker D7W
# New match found: DeviceId 23973 matches StreetMarker C192
# New match found: DeviceId 25105 matches StreetMarker 7027S
# New match found: DeviceId 26504 matches StreetMarker 13056N
# New match found: DeviceId 26684 matches StreetMarker C6938
# New match found: DeviceId 26389 matches StreetMarker 1388E
# New match found: DeviceId 26887 matches StreetMarker 3198N
# New match found: DeviceId 26673 matches StreetMarker 3464N
# New match found: DeviceId 26008 matches StreetMarker 1394E
# New match found: DeviceId 26824 matches StreetMarker C744
# New match found: DeviceId 26104 matches StreetMarker 13604E
# New match found: DeviceId 26581 matches StreetMarker C7178
# New match found: DeviceId 25873 matches StreetMarker C5576
# New match found: DeviceId 25209 matches StreetMarker C1004
# New match found: DeviceId 25819 matches StreetMarker C2940
# New match found: DeviceId 26656 matches StreetMarker 1775S
# New match found: DeviceId 27058 matches StreetMarker C2646
# New match found: DeviceId 25915 matches StreetMarker 13083S
# New match found: DeviceId 26265 matches StreetMarker 7599S
# New match found: DeviceId 26879 matches StreetMarker 2399S
# New match found: DeviceId 25942 matches StreetMarker 1494E
# New match found: DeviceId 26191 matches StreetMarker 1977S
# New match found: DeviceId 24938 matches StreetMarker 3978N
# New match found: DeviceId 25670 matches StreetMarker 3279S
# New match found: DeviceId 25733 matches StreetMarker C5858
# New match found: DeviceId 25340 matches StreetMarker 15010E
# New match found: DeviceId 27506 matches StreetMarker 13250N
# New match found: DeviceId 26658 matches StreetMarker 1988N
# New match found: DeviceId 23983 matches StreetMarker 2851S
# New match found: DeviceId 23981 matches StreetMarker 1316E
# New match found: DeviceId 23980 matches StreetMarker 9897S
# New match found: DeviceId 23978 matches StreetMarker C6178
# New match found: DeviceId 23977 matches StreetMarker C7190
# New match found: DeviceId 23979 matches StreetMarker C6414
# New match found: DeviceId 23975 matches StreetMarker C6930
# New match found: DeviceId 23976 matches StreetMarker 5476E
# New match found: DeviceId 23982 matches StreetMarker C496
# New match found: DeviceId 27434 matches StreetMarker 3302N
# New match found: DeviceId 24921 matches StreetMarker C6838
# New match found: DeviceId 26193 matches StreetMarker 13038N
# New match found: DeviceId 26982 matches StreetMarker 9903S
# New match found: DeviceId 27499 matches StreetMarker 3262N
# New match found: DeviceId 25669 matches StreetMarker 3277S
# New match found: DeviceId 26474 matches StreetMarker 2682N
# New match found: DeviceId 27500 matches StreetMarker 3258N
# New match found: DeviceId 26368 matches StreetMarker C232
# New match found: DeviceId 27052 matches StreetMarker 1916N
# New match found: DeviceId 26643 matches StreetMarker 1473W
# New match found: DeviceId 26287 matches StreetMarker 10192E
# New match found: DeviceId 26660 matches StreetMarker 2244N
# New match found: DeviceId 26339 matches StreetMarker 2206N
# New match found: DeviceId 26820 matches StreetMarker C790
# New match found: DeviceId 27040 matches StreetMarker C1126
# New match found: DeviceId 27249 matches StreetMarker 3940N
# New match found: DeviceId 26076 matches StreetMarker 5066E
# New match found: DeviceId 27268 matches StreetMarker 13302E
# New match found: DeviceId 28092 matches StreetMarker 9898N
# New match found: DeviceId 27407 matches StreetMarker 13262N
# New match found: DeviceId 25219 matches StreetMarker C1260
# New match found: DeviceId 25108 matches StreetMarker C7042
# New match found: DeviceId 26175 matches StreetMarker 1207W
# New match found: DeviceId 25051 matches StreetMarker 2510N
# New match found: DeviceId 23984 matches StreetMarker 4899W
# New match found: DeviceId 23987 matches StreetMarker 7033S
# New match found: DeviceId 26384 matches StreetMarker 1465W
# New match found: DeviceId 23991 matches StreetMarker 6205W
# New match found: DeviceId 23989 matches StreetMarker C5768
# New match found: DeviceId 23990 matches StreetMarker C5936
# New match found: DeviceId 23986 matches StreetMarker C6902
# New match found: DeviceId 25539 matches StreetMarker 15213S
# New match found: DeviceId 25553 matches StreetMarker 15241S
# New match found: DeviceId 27469 matches StreetMarker C6038
# New match found: DeviceId 25605 matches StreetMarker 15259S
# New match found: DeviceId 25959 matches StreetMarker C7176
# New match found: DeviceId 26688 matches StreetMarker C5728
# New match found: DeviceId 26087 matches StreetMarker 10185W
# New match found: DeviceId 25435 matches StreetMarker 15096E
# New match found: DeviceId 28178 matches StreetMarker C442
# New match found: DeviceId 26334 matches StreetMarker 13021S
# New match found: DeviceId 24563 matches StreetMarker 2625S
# New match found: DeviceId 25805 matches StreetMarker C7240
# New match found: DeviceId 25077 matches StreetMarker 4099W
# New match found: DeviceId 25824 matches StreetMarker 91W
# New match found: DeviceId 26543 matches StreetMarker 1344E
# New match found: DeviceId 27472 matches StreetMarker 11709W
# New match found: DeviceId 26067 matches StreetMarker C5718
# New match found: DeviceId 28237 matches StreetMarker 13736E
# New match found: DeviceId 25233 matches StreetMarker C1210
# New match found: DeviceId 25925 matches StreetMarker C2844
# New match found: DeviceId 24434 matches StreetMarker 1297W
# New match found: DeviceId 23995 matches StreetMarker 13007S
# New match found: DeviceId 23994 matches StreetMarker 2037S
# New match found: DeviceId 23996 matches StreetMarker 13283S
# New match found: DeviceId 23993 matches StreetMarker 13412E
# New match found: DeviceId 25909 matches StreetMarker 12514N
# New match found: DeviceId 27394 matches StreetMarker 1343W
# New match found: DeviceId 25272 matches StreetMarker 15554N
# New match found: DeviceId 26108 matches StreetMarker C644
# New match found: DeviceId 25525 matches StreetMarker 15192N
# New match found: DeviceId 26576 matches StreetMarker 7037S
# New match found: DeviceId 26567 matches StreetMarker 1468E
# New match found: DeviceId 25965 matches StreetMarker 1461W
# New match found: DeviceId 25470 matches StreetMarker 15131S
# New match found: DeviceId 26572 matches StreetMarker 4517W
# New match found: DeviceId 24525 matches StreetMarker 5314E
# New match found: DeviceId 27528 matches StreetMarker 12225S
# New match found: DeviceId 26484 matches StreetMarker C3072
# New match found: DeviceId 27171 matches StreetMarker 13003S
# New match found: DeviceId 26599 matches StreetMarker 12504N
# New match found: DeviceId 24557 matches StreetMarker 1912N
# New match found: DeviceId 28192 matches StreetMarker 2402N
# New match found: DeviceId 27046 matches StreetMarker 1492E
# New match found: DeviceId 26529 matches StreetMarker C826
# New match found: DeviceId 26002 matches StreetMarker 909W
# New match found: DeviceId 28012 matches StreetMarker 20375W
# New match found: DeviceId 26987 matches StreetMarker 13769W
# New match found: DeviceId 23999 matches StreetMarker C1218
# New match found: DeviceId 24002 matches StreetMarker 448E
# New match found: DeviceId 24001 matches StreetMarker 673W
# New match found: DeviceId 23998 matches StreetMarker 13472E
# New match found: DeviceId 23997 matches StreetMarker 13800N
# New match found: DeviceId 26839 matches StreetMarker 1295W
# New match found: DeviceId 24993 matches StreetMarker 7578N
# New match found: DeviceId 25976 matches StreetMarker C7746
# New match found: DeviceId 26675 matches StreetMarker 3338N
# New match found: DeviceId 25267 matches StreetMarker 15544N
# New match found: DeviceId 24892 matches StreetMarker 10184E
# New match found: DeviceId 24873 matches StreetMarker 13024N
# New match found: DeviceId 25694 matches StreetMarker 11878E
# New match found: DeviceId 25114 matches StreetMarker 7590N
# New match found: DeviceId 26390 matches StreetMarker 1386E
# New match found: DeviceId 26483 matches StreetMarker C3014
# New match found: DeviceId 27250 matches StreetMarker 3936N
# Unique DeviceIds: 307
# Unique StreetMarkers: 307

# %% [markdown]
# ### Time variable decomposition

# %%
# Extract the 'Hour' from ArrivalTime to analyze behavior by hour of the day
df_500k_mod['Hour'] = df_500k_mod['ArrivalTime'].dt.hour
df_500k_mod['WeekDay'] = df_500k_mod['ArrivalTime'].dt.weekday
df_500k_mod['Month'] = df_500k_mod['ArrivalTime'].dt.month

# %% [markdown]
# ### Gráficas ilustrativas

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# Set colors for VehiclePresent: False -> orange, True -> green
set2_colors = sns.color_palette('Set2', 2)
palette_vehicle_present = {False: set2_colors[1], True: set2_colors[0]}
hue_order_vehicle_present = [False, True]

# Observe Target distribution to check class balance
sns.countplot(
    data=df_500k_mod,
    x='VehiclePresent',
    hue='VehiclePresent',
    hue_order=hue_order_vehicle_present,
    palette=palette_vehicle_present,
    ax=axes[0],
    legend=False
)
axes[0].set_title('Distribución de VehiclePresent (TARGET)', fontsize=14)
axes[0].set_xlabel('Bool presencia', fontsize=12)
axes[0].set_ylabel('Cantidad de Registros', fontsize=12)

# Distribution of DurationMinutes separated by target
mask_duracion = df_500k_mod['DurationMinutes'] < 300
sns.histplot(
    data=df_500k_mod[mask_duracion],
    x='DurationMinutes',
    hue='VehiclePresent',
    hue_order=hue_order_vehicle_present,
    bins=50,
    kde=True,
    palette=palette_vehicle_present,
    ax=axes[1]
)
axes[1].set_xticks(range(0, 300, 20))
axes[1].tick_params(axis='x', rotation=45)
axes[1].set_title('Duración en minutos en función de ocupación', fontsize=14)
axes[1].set_xlabel('Duración (Minutos)', fontsize=12)
axes[1].set_ylabel('Frecuencia', fontsize=12)


plt.tight_layout()
plt.show()

# %%
# Charts showing behavior by hour, day of week, and month of year
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(1, 3, figsize=(24, 6))
# Chart by hour of day
sns.countplot(
    data=df_500k_mod,
    x='Hour',
    hue='VehiclePresent',
    hue_order=hue_order_vehicle_present,
    palette=palette_vehicle_present,
    ax=axes[0]
)
axes[0].set_title('Distribución de VehiclePresent por Hora del Día', fontsize=14)
axes[0].set_xlabel('Hora del Día', fontsize=12)
axes[0].set_ylabel('Cantidad de Registros', fontsize=12)
axes[0].set_xticks(range(0, 24))
axes[0].tick_params(axis='x', rotation=45)

# Chart by day of week
sns.countplot(
    data=df_500k_mod,
    x='WeekDay',
    hue='VehiclePresent',
    hue_order=hue_order_vehicle_present,
    palette=palette_vehicle_present,
    ax=axes[1]
)
axes[1].set_title('Distribución de VehiclePresent por Día de la Semana', fontsize=14)
axes[1].set_xlabel('Día de la Semana (0=Lunes, 6=Domingo)', fontsize=12)
axes[1].set_ylabel('Cantidad de Registros', fontsize=12)
axes[1].set_xticks(range(0, 7))
axes[1].tick_params(axis='x', rotation=45)

# Chart by month of year
sns.countplot(
    data=df_500k_mod,
    x='Month',
    hue='VehiclePresent',
    hue_order=hue_order_vehicle_present,
    palette=palette_vehicle_present,
    ax=axes[2]
)
axes[2].set_title('Distribución de VehiclePresent por Mes del Año', fontsize=14)
axes[2].set_xlabel('Mes del Año', fontsize=12)
axes[2].set_ylabel('Cantidad de Registros', fontsize=12)
axes[2].set_xticks(range(1, 13))
axes[2].tick_params(axis='x', rotation=45) 
plt.tight_layout()
plt.show()

# %%
# Average occupied DeviceIds per hour
occupied_intervals = df_500k_mod[df_500k_mod['VehiclePresent'] == True].copy()

# Round to hour to build the occupied hourly interval
occupied_intervals['start_hour'] = occupied_intervals['ArrivalTime'].dt.floor('h')
occupied_intervals['end_hour'] = occupied_intervals['DepartureTime'].dt.ceil('h')

# Ensure at least one hour per interval (avoids empty intervals)
same_hour_mask = occupied_intervals['end_hour'] <= occupied_intervals['start_hour']
occupied_intervals.loc[same_hour_mask, 'end_hour'] = occupied_intervals.loc[same_hour_mask, 'start_hour'] + pd.Timedelta(hours=1)

# Expand each interval into hours
occupied_intervals['hour_range'] = occupied_intervals.apply(
    lambda row: pd.date_range(start=row['start_hour'], end=row['end_hour'], freq='h', inclusive='left'),
    axis=1
)

occupied_by_hour = (
    occupied_intervals[['DeviceId', 'hour_range']]
    .explode('hour_range')
    .dropna(subset=['hour_range'])
)

occupied_per_timestamp = occupied_by_hour.groupby('hour_range')['DeviceId'].nunique()
# Average profile by hour of day (0-23)
mean_occupied_by_hour = (
    occupied_per_timestamp
    .groupby(occupied_per_timestamp.index.hour)
    .mean()
    .reindex(range(24), fill_value=0)
)

plt.figure(figsize=(12, 5))
plt.bar(mean_occupied_by_hour.index, mean_occupied_by_hour.values, color='seagreen', alpha=0.85)
plt.xticks(range(24))
plt.xlabel('Hora del día')
plt.ylabel('DeviceId ocupados (promedio)')
plt.title('Ocupación media por hora')
plt.grid(axis='y', alpha=0.25)
plt.tight_layout()
plt.show()

peak_hour = int(mean_occupied_by_hour.idxmax())
peak_value = float(mean_occupied_by_hour.max())
print(f"Hora pico de ocupación: {peak_hour}:00")
print(f"DeviceId ocupados promedio en hora pico: {peak_value:.2f}")
print(f"Porcentaje de DeviceId ocupados en hora pico: {(peak_value / unique_values['DeviceId']) * 100:.2f}%")
# Out:
# Hora pico de ocupación: 13:00
# DeviceId ocupados promedio en hora pico: 42.03
# Porcentaje de DeviceId ocupados en hora pico: 13.69%

# %% [markdown]
# ### Outliers

# %%
# DurationMinutes is the only continuous variable

set2_colors = sns.color_palette('Set2', 2)
palette_vehicle_present = {False: set2_colors[1], True: set2_colors[0]}
hue_order_vehicle_present = [False, True]

plt.figure(figsize=(10, 4))
# Log-scale due to long-tailed distribution
sns.boxplot(data=df_500k_mod, x='DurationMinutes', hue='VehiclePresent', hue_order=hue_order_vehicle_present, palette=palette_vehicle_present, orient='h')
plt.xscale('log')
plt.title('Detección de Outliers en Duración (Minutos)')
plt.show()

# %% [markdown]
# ## Feature selection para posterior entrenamiento

# %%
# To avoid data leakage, some variables are discarded
selected_feat = ['DeviceId', 'StreetId', 'ArrivalTime', 'DepartureTime', 'Hour', 'WeekDay', 'Month', 'VehiclePresent']

df_500k_model = df_500k_mod[selected_feat].copy()
df_500k_model.info()
display(df_500k_model.head())
df_500k_model.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DeviceId        500000 non-null  int64
#  1   StreetId        500000 non-null  int64
#  2   ArrivalTime     500000 non-null  datetime64[us]
#  3   DepartureTime   500000 non-null  datetime64[us]
#  4   Hour            500000 non-null  int32
#  5   WeekDay         500000 non-null  int32
#  6   Month           500000 non-null  int32
#  7   VehiclePresent  500000 non-null  bool
# dtypes: bool(1), datetime64[us](2), int32(3), int64(2)
# memory usage: 21.5 MB
#    DeviceId  StreetId         ArrivalTime       DepartureTime  Hour  WeekDay  \
# 0     23915       123 2019-11-03 03:00:56 2019-11-03 03:07:26     3        6
# 1     23914       528 2019-04-16 14:14:47 2019-04-16 14:15:23    14        1
# 2     23913       670 2019-09-29 01:08:22 2019-09-29 01:31:41     1        6
# 3     23915       123 2019-06-05 18:59:17 2019-06-05 18:59:24    18        2
# 4     23915       123 2019-04-01 07:03:41 2019-04-01 07:14:12     7        0
#
#    Month  VehiclePresent
# 0     11           False
# 1      4           False
# 2      9           False
# 3      6           False
# 4      4            True
# DeviceId          0
# StreetId          0
# ArrivalTime       0
# DepartureTime     0
# Hour              0
# WeekDay           0
# Month             0
# VehiclePresent    0
# dtype: int64

# %% [markdown]
# ## Export to parquet

# %%
# Export to parquet for faster loading in future steps
parquet_path = os.path.join(data_folder, "df_500k_processed.parquet")
df_500k_model.to_parquet(parquet_path, index=False)
print(f"DataFrame exportado a {parquet_path}")
# Out:
# DataFrame exportado a ../../data/df_500k_processed.parquet
